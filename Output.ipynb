# %%
# %run main.py
#decision tree
# Out:
# Length of Training Data:  (4920, 134)
# Training Features:  (4920, 132)
# Training Labels:  (4920,)
# Length of Test Data:  (42, 133)
# Test Features:  (42, 132)
# Test Labels:  (42,)
# Number of Training Features: 3296	Number of Training Labels: 3296
# Number of Validation Features: 1624	Number of Validation Labels: 1624
#
# Training Accuracy:  1.0
#
# Validation Prediction:  ['Osteoarthristis' 'Allergy' 'Alcoholic hepatitis' ...
#  'Dimorphic hemmorhoids(piles)' 'GERD' 'Pneumonia']
#
# Validation Accuracy:  1.0
#
# Validation Confusion Matrix:
#  [[47  0  0 ...  0  0  0]
#  [ 0 50  0 ...  0  0  0]
#  [ 0  0 41 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 35  0  0]
#  [ 0  0  0 ...  0 39  0]
#  [ 0  0  0 ...  0  0 44]]
#
# Cross Validation Score:
#  [0.97232472 0.92791128 0.96118299]
#
# Classification Report:
#                                           precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00        47
# ...

# %%
# %run main.py
#random forest
# Out:
# Length of Training Data:  (4920, 134)
# Training Features:  (4920, 132)
# Training Labels:  (4920,)
# Length of Test Data:  (42, 133)
# Test Features:  (42, 132)
# Test Labels:  (42,)
# Number of Training Features: 3296	Number of Training Labels: 3296
# Number of Validation Features: 1624	Number of Validation Labels: 1624
#
# Training Accuracy:  1.0
#
# Validation Prediction:  ['Osteoarthristis' 'Allergy' 'Alcoholic hepatitis' ...
#  'Dimorphic hemmorhoids(piles)' 'GERD' 'Pneumonia']
#
# Validation Accuracy:  1.0
#
# Validation Confusion Matrix:
#  [[47  0  0 ...  0  0  0]
#  [ 0 50  0 ...  0  0  0]
#  [ 0  0 41 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 35  0  0]
#  [ 0  0  0 ...  0 39  0]
#  [ 0  0  0 ...  0  0 44]]
#
# Cross Validation Score:
#  [0.99815498 0.99445471 1.        ]
#
# Classification Report:
#                                           precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00        47
# ...

# %%
# gradient_boost
# %run main.py
# Out:
# Length of Training Data:  (4920, 134)
# Training Features:  (4920, 132)
# Training Labels:  (4920,)
# Length of Test Data:  (42, 133)
# Test Features:  (42, 132)
# Test Labels:  (42,)
# Number of Training Features: 3296	Number of Training Labels: 3296
# Number of Validation Features: 1624	Number of Validation Labels: 1624
#
# Training Accuracy:  1.0
#
# Validation Prediction:  ['Osteoarthristis' 'Allergy' 'Alcoholic hepatitis' ...
#  'Dimorphic hemmorhoids(piles)' 'GERD' 'Pneumonia']
#
# Validation Accuracy:  1.0
#
# Validation Confusion Matrix:
#  [[47  0  0 ...  0  0  0]
#  [ 0 50  0 ...  0  0  0]
#  [ 0  0 41 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 35  0  0]
#  [ 0  0  0 ...  0 39  0]
#  [ 0  0  0 ...  0  0 44]]
#
# Cross Validation Score:
#  [0.98523985 0.98151571 0.99445471]
#
# Classification Report:
#                                           precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00        47
# ...

# %%
# %run infer.py
# Out:
# Predicted Disease: ['Fungal infection']

# %%
# %run infer.py
# Out:
# Predicted Disease: ['Allergy']

# %%
# %run infer.py
# Out:
# Predicted Disease: ['Pneumonia']

# %%
# %run infer.py
# Out:
# Predicted Disease from random_forest: ['Pneumonia']
# Predicted Disease from decision trees: ['Allergy']
# Predicted Disease from gradient Boost: ['Tuberculosis']

# %%
# %run infer.py
# Out:
# Predicted Disease from random_forest: ['Fungal infection']
# Predicted Disease from decision trees: ['Fungal infection']
# Predicted Disease from gradient Boost: ['Impetigo']

# %%
# %run evaluation.py

# %%
# %run infer.py
# Out:
# Predicted Disease from random_forest: ['Acne']
# Predicted Disease from decision trees: ['Fungal infection']
# Predicted Disease from gradient Boost: ['Impetigo']

# %%
# %run infer.py
# Out:
# Predicted Disease from random_forest: ['Fungal infection']
# Predicted Disease from decision trees: ['Fungal infection']
# Predicted Disease from gradient Boost: ['Fungal infection']

# %%
# %run infer.py
# Out:
# Predicted Disease from random_forest: ['Fungal infection']
# Predicted Disease from decision trees: ['Fungal infection']
# Predicted Disease from gradient Boost: ['Fungal infection']
